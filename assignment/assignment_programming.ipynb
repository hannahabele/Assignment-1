# %% [markdown]
# # Assignment: Programming Review
# ## Do Q1 and one other question.

# %% [markdown]
# **Q1.** First, think about your priorities in life. What kind of salary do you want to make after graduation? Do you mind getting more schooling? What kind of work-life balance are you looking for? Where do you want to work, geographically? You don't have to write this down here, just think about it.
#
# 1. Go to the Occupational Outlook Handbook at [https://www.bls.gov/ooh/](https://www.bls.gov/ooh/). Look up "Data Scientist." Read about the job and start collecting data about it from the job profile (e.g. salary, education required, work setting)
# 2. Find 7-10 other jobs that appeal to you, and collect the same data as you did for Data Scientist. Put it all in a spreadsheet.
# 3. Do any of your findings surprise you?
# 4. Rank the jobs you picked from best to worst, and briefly explain why you did so.
# 5. Please submit your spreadsheet with the assignment --- you can "de-identify" it and remove anything that you find personally identifying or you don't want to share, of course. We'll play with these data later.

# %% [markdown]
# Some of the findings surprise me a lot from the research associated with this assignment. I assumed that the number of jobs for each occupation would increase due to the population increasing, but I did not consider technology and AI. With new technology, humans are no longer needed to perform certain jobs. I know there was a wave of installing self-checkout counters in stores, but I had read an article mentioning companies decreasing the number of self-checkout lanes in order to increase the number of jobs and hire more cashiers. Therefore, the number of jobs projected for 2033 for cashiers surprised me. The largest shock though was the projected decrease in the number of computer programmers. Computer programming, in the past couple of decades, has been an extremely popular field so it is shocking that the number of jobs in the field is projected to decrease. Even though this decrease could be due to AI, the AI technology is not advanced enough yet to take over the entire computer programming field. I would rank Data Scientist as the best because there is not a lot of schooling needed to make a large salary with the field also growing exponentially. Next I would rank physician as number 2, lawyer at 3, financial analyst at 4, and architect at 5. Physicians and lawyers must go through a lot of extra education which is why I don't have them at 1, but they make a lot of money and both fields are still projected to grow. Financial analyst and architect are next because they have good pay, not as good as physician and lawyer, but don't need a lot of extra school. For the bottom 3, I would rank computer programmer at 6, tractor-trailer and truck driver at 7, and casheir at 8. The number of computer programming and cashier jobs is expected to decrease which is why they are low. Tractor-trailer truck driver is also low because it is not very fun to spend all day in a truck for only making around $54,000 a year.

# %% [markdown]
# **Q2.** Being able to make basic plots to visualize sets of points is really helpful, particularly with data analysis. The pyplot plots are built up slowly by defining elements of the plot, and then using `plt.show()` to create the final plot. This question gives you some practice doing that **iterative** building process.
#
# 1. Import the `numpy` module as `np` and the `matplotlib.pyplot` package as `plt`.
# 2. Use `np.linspace` to create a grid of 50 points ranging from 0 to 1.
# 3. Create a numpy array $y$ containing the values for the natural logarithm function using the `np.log(x)` function. Create a numpy array $z$ containing the values for the exponential function using the `np.exp(x)` function.
# 4. Use the `plt.scatter(x,y)` method for the $y$ and $z$ vectors to create two scatter plots of the points you've created.
# 5. Use the `plt.show()` method to create the plot.
#
# That plot has some problems.
#
# 6. Before the `plt.show()` call, add labels to the $x$ and $y$ axes using `plt.xlabel(label)` and `plt.ylabel(label)`. Add a title to the graph using `plt.title(title)`, like "Natural Log and Exponential Functions".
# 7. That looks a lot better, but we need a legend. When you screate the scatter plots, add the argument `label='Natural Log'` or `label='Exponential'` to the `.scatter` method call. Before the `plt.show()` call, add a `plt.legend(loc = 'lower right')` method call, which creates a legend in the lower right.
#
# Now do it again, with slightly less direction:
#
# 8. Create a grid of 100 equally spaced points ranging from -6.5 to 6.5.
# 9. Use the sine and cosine functions in Numpy to compute the values of those functions for each point on your grid. (You'll have to find out what those functions are.)
# 10. Plot the values of the two functions for the values on the grid on the same plot.
# 11. The scatter plot looks really noisy. Instead of `plt.scatter(x,y)` to make a scatter plot, use `plt.plot(x,y)` to make a line graph.
# 12. Make the plot again, with labels for the axes, a title, and a legend in the lower left instead of the lower right.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Use np.linspace to create a grid of 50 points ranging from 0 to 1.

# %%
points = np.linspace(0,1,50)

# %% [markdown]
# Create a numpy array  𝑦  containing the values for the natural logarithm function using the np.log(x) function. Create a numpy array  𝑧  containing the values for the exponential function using the np.exp(x) function.

# %%
log_points = np.log(points)
exp_points = np.exp(points)
# Out:
# <ipython-input-4-c8a12166a064>:1: RuntimeWarning: divide by zero encountered in log
#   y = np.log(points)

# %% [markdown]
# Use the plt.scatter(x,y) method for the  𝑦  and  𝑧  vectors to create two scatter plots of the points you've created. Use the plt.show() method to create the plot.

# %%
plt.scatter(points,log_points)
plt.scatter(points,exp_points)
plt.show()

# %% [markdown]
# Before the plt.show() call, add labels to the  𝑥  and  𝑦  axes using plt.xlabel(label) and plt.ylabel(label). Add a title to the graph using plt.title(title), like "Natural Log and Exponential Functions".

# %%
plt.xlabel('X')
plt.ylabel('Y')
plt.title("Natural Log and Exponential Function Graph")
# Out:
# Text(0.5, 1.0, 'Natural Log and Exponential Function Graph')

# %% [markdown]
# That looks a lot better, but we need a legend. When you screate the scatter plots, add the argument label='Natural Log' or label='Exponential' to the .scatter method call. Before the plt.show() call, add a plt.legend(loc = 'lower right') method call, which creates a legend in the lower right.

# %%
plt.scatter(points, log_points, label = "Natural Log")
plt.scatter(points, exp_points, label = "Exponential Function")
plt.legend(loc = "lower right")
plt.show()

# %% [markdown]
# Create a grid of 100 equally spaced points ranging from -6.5 to 6.5.

# %%
points2 = np.linspace(-6.5,6.5,100)

# %% [markdown]
# Use the sine and cosine functions in Numpy to compute the values of those functions for each point on your grid. (You'll have to find out what those functions are.)

# %%
sine = np.sin(points2)
cosine = np.cos(points2)

# %% [markdown]
# Plot the values of the two functions for the values on the grid on the same plot.

# %%
plt.scatter(points2, sine)
plt.scatter(points2, cosine)
plt.show()

# %% [markdown]
# The scatter plot looks really noisy. Instead of plt.scatter(x,y) to make a scatter plot, use plt.plot(x,y) to make a line graph.

# %%
plt.plot(points2, sine, label = "Sine")
plt.plot(points2,cosine, label = "Cosine")
plt.show()

# %% [markdown]
# Make the plot again, with labels for the axes, a title, and a legend in the lower left instead of the lower right.

# %%
plt.xlabel('X')
plt.ylabel('Y')
plt.title("Sine & Cosine Function Graph")
plt.plot(points2, sine, label = "Sine")
plt.plot(points2, cosine, label = "Cosine")
plt.legend(loc = "lower left")
plt.show()
